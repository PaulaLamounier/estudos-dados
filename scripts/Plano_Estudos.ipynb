# %% [markdown]
# # Plano de Estudos: Engenharia de Dados, IA e Python
#
# Este notebook será seu guia para evoluir em Engenharia de Dados, Inteligência Artificial e Python.

# %% [markdown]
# ## Fase 1: Fundamentos de Python e Análise de Dados (1 mês)
#
# **Objetivo:** Dominar Python e bibliotecas essenciais para análise.
#
# **Tópicos:**
# - Sintaxe básica, estruturas de dados, funções
# - Manipulação de dados com **Pandas**
# - Operações numéricas com **NumPy**
# - Visualização com **Matplotlib** e **Seaborn**
#
# **Links úteis:**
# - [Documentação Pandas](https://pandas.pydata.org/docs/)
# - [Documentação NumPy](https://numpy.org/doc/)
# - [Matplotlib](https://matplotlib.org/stable/contents.html)
# - [Seaborn](https://seaborn.pydata.org/)
#
# **Prática:**
# - Analisar um dataset simples do Kaggle
# - Criar gráficos e relatórios

# %%
# Espaço para prática com Python
# Exemplo: importar pandas e carregar um dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Fase 2: Engenharia de Dados (2 meses)
#
# **Objetivo:** Entender pipelines, ETL e ferramentas do mercado.
#
# **Tópicos:**
# - SQL avançado (joins, índices, otimização)
# - ETL e transformação de dados
# - Ferramentas: **Apache Spark**, **Airflow**, **Docker**
# - Introdução a Big Data
#
# **Links úteis:**
# - [Documentação Spark](https://spark.apache.org/docs/latest/)
# - [Airflow](https://airflow.apache.org/docs/)
# - [Docker](https://docs.docker.com/)
#
# **Prática:**
# - Criar um pipeline simples com Airflow
# - Processar dados com Spark

# %%
# Espaço para prática com SQL ou Spark
# Exemplo: conexão com banco de dados ou criação de DataFrame Spark

# %% [markdown]
# ## Fase 3: Inteligência Artificial e Machine Learning (2 meses)
#
# **Objetivo:** Construir modelos e entender conceitos de IA.
#
# **Tópicos:**
# - Pré-processamento de dados
# - Modelos clássicos com **Scikit-learn**
# - Redes neurais com **TensorFlow** ou **PyTorch**
#
# **Links úteis:**
# - [Scikit-learn](https://scikit-learn.org/stable/)
# - [TensorFlow](https://www.tensorflow.org/tutorials)
# - [PyTorch](https://pytorch.org/tutorials/)
#
# **Prática:**
# - Criar um modelo de previsão (ex.: vendas)
# - Implementar uma rede neural simples

# %%
# Espaço para prática com Machine Learning
# Exemplo: importar scikit-learn e criar um modelo simples

# %% [markdown]
# ## Fase 4: Portfólio e Projetos (1 mês)
#
# **Objetivo:** Consolidar conhecimento e mostrar resultados.
#
# **Tópicos:**
# - Publicar projetos no GitHub
# - Documentação e boas práticas
# - Explorar desafios no Kaggle
#
# **Links úteis:**
# - [GitHub Docs](https://docs.github.com/)
# - [Kaggle](https://www.kaggle.com/)
#
# **Prática:**
# - Criar 2 projetos completos (ETL + análise + modelo)

# %%
# Espaço para anotações e links para seus projetos
